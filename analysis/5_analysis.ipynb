# %% [markdown]
# ### Questions

# %% [markdown]
# # Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib_venn import venn2, venn3
import ptitprince as pt

# %%
pd.set_option("display.precision", 2)
sns.set_style("darkgrid")

# %%
articles_csv = "../data/plos_ncbi.csv"
metrics_csv = "../data/metrics.csv"
details_csv = "../data/details.csv"

# %% [markdown]
# ### Load details and metrics

# %%
articles = pd.read_csv(articles_csv, index_col="doi", parse_dates=['publication_date'])
articles['year'] = articles.publication_date.map(lambda x: x.year)

details = pd.read_csv(details_csv, index_col="id", parse_dates=['received_at', 'og_updated_time', 'publication_date', 'added_on'])
details['year'] = details.publication_date.map(lambda x: x.year)

metrics = pd.read_csv(metrics_csv, index_col="doi")
metrics.rename(columns={'facebook': 'public_fb',
                        'shares': 'private_fb_api',
                        'diff': 'fb_diff_api',
                        'reactions': 'fb_reactions_api',
                        'comments' : 'fb_comments_api'}, inplace=True)
del metrics['total']

# Only keep non-zero engagement numbers
for _ in ['private_fb', 'fb_comments', 'fb_reactions']:
    metrics[_] = metrics[_+"_api"][metrics[_+"_api"] != 0]
metrics['diff'] = metrics['private_fb'] - metrics['public_fb']

# %%
diff_ogids = details.groupby(["doi", "og_id"]).size().groupby(['og_id']).count()
temp = diff_ogids.value_counts()
df = pd.concat([temp, (100*temp/temp.sum()).astype(object)], axis=1)
df.columns = ["og_ids", "%"]
df.index.name = "dois sharing same og_id"
df.sort_index()
# Out:
#                          og_ids        %
# dois sharing same og_id
# 1                        123552    1e+02
# 2                           113    0.091
# 3                           138     0.11
# 4                             5    0.004
# 5                             1  0.00081
# 33                            1  0.00081
# 754                           1  0.00081

# %%
bad_ogids = diff_ogids[diff_ogids>1].keys()
a = len(metrics.loc[details[details.og_id.isin(bad_ogids)].doi])
dropped_years = details[details.og_id.isin(bad_ogids)].drop_duplicates(subset="doi").year.value_counts()

metrics = metrics.drop(metrics.loc[details[details.og_id.isin(bad_ogids)].doi].index, axis=0)
details = details.drop(details[details.og_id.isin(bad_ogids)].index, axis=0)

# %%
print("Duplicate og_ids: {}".format(len(bad_ogids)))
print("Dropped articles: {} ({:.2f}%)".format(a, 100 * a / articles.shape[0]))
print("Dropped articles | Years:")
dropped_years.sum()
# Out:
# Duplicate og_ids: 259
# Dropped articles: 1863 (1.59%)
# Dropped articles | Years:
# 963

# %% [markdown]
# # Useful indices, slices, etc

# %%
yearly_articles = {}
for year in range(2013, 2018):
    yearly_articles[year] = set(details[details.year==year].doi.tolist())

public_shares = set(metrics['public_fb'].dropna().index.tolist())
twitter = set(metrics['twitter'].dropna().index.tolist())

private_shares = set(metrics['private_fb'].dropna().index.tolist())
private_reactions = set(metrics.fb_reactions.dropna().index.tolist())
private_comments = set(metrics.fb_comments.dropna().index.tolist())

any_shares = public_shares.union(private_shares)
both_shares = public_shares.intersection(private_shares)

any_engagement = private_shares.union(private_reactions).union(private_comments)

# %% [markdown]
# # Basic stats

# %%
venn3([private_shares, private_reactions, private_comments],
      set_labels=('shares', 'reactions', 'comments'),
      subset_label_formatter=lambda x: "{} ({:.1f})".format(x, 100*x/len(engagement)));
# Out:
# 34886
# 34574
# 21491
# 16350

# %%
print("Any:", len(any_engagement))
print("shares:", len(private_shares))
print("reactions:", len(private_reactions))
print("comments:", len(private_comments))

print("reactions/shares: {} {:.1f}".format(len(private_shares.intersection(private_reactions)),
                                           100*len(private_shares.intersection(private_reactions))/len(private_shares)))
print("comments/shares: {} {:.1f}".format(len(private_shares.intersection(private_comments)),
                                          100*len(private_shares.intersection(private_comments))/len(private_shares)))
print("reactions&comments/shares: {} {:.1f}".format(len(private_shares.intersection(private_comments).intersection(private_reactions)),
                                                    100*len(private_shares.intersection(private_comments).intersection(private_reactions))/len(private_shares)))
# Out:
# Any: 34886
# shares: 34574
# reactions: 21491
# comments: 16350
# reactions/shares: 21195 61.3
# comments/shares: 16168 46.8
# reactions&comments/shares: 14460 41.8

# %%
df = pd.DataFrame(columns=['total', 'engagement'])
df['total'] = articles.year.value_counts()
df['engagement'] = details[details.doi.isin(any_engagement)].year.value_counts()
df['%'] = 100 * df['engagement'] / df['total']
df = df.reset_index()
df['index'] = df['index'].astype(str)

pdf = df.melt(id_vars="index", value_vars=['total', 'engagement'], value_name="count")

# %%
ax = sns.barplot(x="index", y="count", hue="variable", data=pdf)

ax2 = ax.twinx()

sns.lineplot(x='index', y="%", data=df, ax=ax2, color="r", legend=False)

ax2.set_ylim(0,100)
ax2.grid('off')

ax.legend(handles=ax.get_legend_handles_labels()[0]+ax2.lines, labels=["Total articles","w/ engagament","Percentage"])

plt.tight_layout()
plt.title("Total articles & ratio");

# %% [markdown]
# ## Coverage

# %%
sources = ['private_fb', 'public_fb', 'twitter', 'reddit']
cp = sns.color_palette(n_colors=len(sources))

pdf = pd.DataFrame(columns=["year", "coverage", "source"])
for source in sources:    
    dois = metrics[source].dropna().index
    df = details[details.doi.isin(dois)].drop_duplicates(subset="doi").year.value_counts()
    
    for year, coverage in df.iteritems():
        pdf.loc[len(pdf)+1] = [year, 100 * coverage / year_counts[year], source]

sns.lmplot(x="year", y="coverage", hue="source", data=pdf, lowess=True)

plt.ylabel("Coverage (%)")
for label in plt.gca().xaxis.get_ticklabels()[::2]:
    label.set_visible(False)

# %%
# Link types that were shared once at least
type_count = details.type.value_counts()
types = pd.concat([type_count, (type_count/type_count.sum()*100).astype(object)], axis=1)
types.columns = ["n", "%"]
types['%'].plot(kind="bar");

# %% [markdown]
# ### Numbers of links that were shared per article

# %%
# How many different links were shared per article
diff_links = details.groupby(["doi"])['og_id'].size()
temp = diff_links.value_counts()
df = pd.concat([temp, (temp/temp.sum()*100).astype(object)], axis=1)
df.columns = ["n", "%"]
df
# Out:
#        n       %
# 1  62271      61
# 2  35321      35
# 3   3250     3.2
# 4    382    0.38
# 5     71    0.07
# 6     16   0.016
# 7      8  0.0079
# 8      5  0.0049

# %% [markdown]
# ### Open Graph IDs per article

# %%
diff_ogids = details.groupby(["doi", "og_id"]).size().groupby(['doi']).count()
temp = diff_ogids.value_counts()
df = pd.concat([temp, (temp/temp.sum()*100).astype(object)], axis=1)
df.columns = ["n", "%"]
df
# Out:
#        n     %
# 1  79546    79
# 2  21328    21
# 3    450  0.44

# %% [markdown]
# ## Comparing public & private distributions
#
# Do the public and private shares follow the same distributions?
#
# By looking at the rank of articles by shares (highest shares -> rank 1, etc) we can compare the nature of the two distributions.
#
# Overall results show that shares follow an exponential distribution in both cases. Scale differende between the two distributions seems to be close to an **order of magnitude**

# %%
cp = sns.color_palette(n_colors=2)

pdf = metrics[['public_fb', 'private_fb']]

pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="min"))], axis=1)
pdf.columns = ['public', 'private', 'public_rank', 'private_rank']

pdf = pdf.apply(lambda x: x.map(lambda x: np.log10(x) if pd.notnull(x) else None))
# pdf = pdf.apply(lambda x: x.map(lambda x: x + np.random.normal(0,.03) if pd.notnull(x) else None))

fig, ax = plt.subplots(figsize=(9, 6))

plt.plot(pdf['private_rank'].dropna(), pdf['private'].dropna(), '.', color=cp[0], alpha=.2, label="Private")
plt.plot(pdf['public_rank'].dropna(), pdf['public'].dropna(), '.', color=cp[1], alpha=.2, label="Public")

plt.title("Article rank vs number of shares")
 
# labels = ["10^{}".format(int(item)) for item in ax.get_xticks().tolist()]
# ax.set_xticklabels(labels)

# labels = ["10^{}".format(int(item)) for item in ax.get_yticks().tolist()]
# ax.set_yticklabels(labels)

ticks = [1, 10, 50, 100, 500, 1000, 5000]
plt.xticks(np.log10(ticks), ticks)
plt.yticks(np.log10(ticks), ticks)

plt.xlabel("Rank")
plt.ylabel("Shares")

plt.legend();

# %% [markdown]
# The same exercise can be repeated for each individual year.
#
# The emerging picture is a bit more complex...
#
# While distributions individually seem to roughly follow exponential growth, the relationship between the distribtions varies over the years. Especially 2014 is standing out, eventually accountable to the amount of data dropped due to data removed previously based on wrongly merged articles by og_ids.

# %%
cp = sns.color_palette(n_colors=2)

fig, axes = plt.subplots(3, 2, figsize=(12, 16), sharex=True, sharey=True)

for year, ax in zip(range(2013, 2018), axes.reshape(-1)):
    pdf = metrics.reindex(details[details.year == year].doi)
    pdf = pdf[['public_fb', 'private_fb']]
    pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="min"))], axis=1)
    pdf.columns = ['public', 'private', 'public_rank', 'private_rank']
    
    ax.plot(pdf['private_rank'].dropna(), pdf['private'].dropna(), '.', color=cp[0], alpha=.2, label="private_fb")
    ax.plot(pdf['public_rank'].dropna(), pdf['public'].dropna(), '.', color=cp[1], alpha=.2, label="public_fb")
    
    ax.set_title(year)
    
    ax.set_xscale("log")
    ax.set_yscale("log")
    
    ax.legend()
    
#fig.add_subplot(111, frameon=False)
#plt.tick_params(labelcolor='none', top='off', bottom='off', left='off', right='off')
#plt.xlabel("log(rank)")
#plt.ylabel("log(shares)");

# %% [markdown]
# ## Most shared link types for articles with up to 2 shared links

# %%
df = pd.DataFrame()
for sel_year in range(2013, 2018):
    pdf = details.loc[details[details.year == sel_year].index]
    diff_links = pdf.groupby(["doi"])['og_id'].size()
    df[sel_year] = 100 * pdf[pdf.doi.isin(diff_links[diff_links <= 2].index)].type.value_counts() / len(pdf)
    # df[sel_year] = pdf[pdf.doi.isin(diff_links[diff_links <= 2].index)].type.value_counts()
df.columns = pd.to_datetime(df.columns, format="%Y")
df.T.plot()

# %% [markdown]
# The old DOI (http://dx.doi.org/[doi]) is slowly not being used anymore. Simultaneously the shares of landing pages has increased.
#
# There was a surge in the number of shared links to the metrics page of articles.
#
# - Is the increased ratio of shared links to landing pages due to a change in infrastructure (share buttons, CrossRef switching to the new DOI) or an indicator of different sharing behaviour?
# - Is that that behaviour because of a change of behaviour in the population of scientists or due to the introduction of a another, differntly behaving population (non-scientists who are not familiar with the sharing of DOIs)?

# %% [markdown]
# ## Coverage

# %%
pdf = metrics

total = len(public_shares.union(private_shares))

venn2([public_shares, private_shares], set_labels=('Public FB', 'Private FB'),
      subset_label_formatter=lambda x: "{} ({:.1f})".format(x, 100*x/total));

# %%
pdf = metrics

total = len(public_set.union(private_set).union(twitter_set))

venn3([twitter_set, public_set, private_set], set_labels=('Twitter', 'Public FB', 'Private FB'),
      subset_label_formatter=lambda x: "{} ({:.1f})".format(x, 100*x/total));

# %%
with sns.axes_style("white"):
    fig, axes = plt.subplots(3, 2, figsize=(12, 16), sharex=True, sharey=True, subplot_kw={'frameon':False})

for year, ax in zip(range(2013, 2018), axes.reshape(-1)):
    ax.set_title(year)
    dois = articles[articles.year == year].index
    pdf = metrics.reindex(dois)

    pub = set(pdf['public_fb'].dropna().index.tolist())
    pri = set(pdf['private_fb'].dropna().index.tolist())

    total = len(pub.union(pri))

    venn2([pub, pri], set_labels=('Public FB', 'Private FB'),ax=ax,
          subset_label_formatter=lambda x: "{} ({:.1f})".format(x, 100*x/total));

# %% [markdown]
# ### Correlations

# %%
cp = sns.color_palette(n_colors=2)

pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf = pdf.sort_values(by='public_fb', ascending=False).iloc[0:1000]

pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="min"))], axis=1)
pdf.columns = ['public', 'private', 'public_rank', 'private_rank']

# v, w = v + np.random.normal(0, .1, len(pdf)), w + np.random.normal(0,.1,len(pdf))
pdf = pdf.apply(lambda x: x.map(lambda x: np.log10(x) if pd.notnull(x) else None))
pdf = pdf.apply(lambda x: x + np.random.normal(0, .1, len(x)), axis=0)

fig, ax = plt.subplots(figsize=(9, 6))

plt.plot(pdf['private_rank'], pdf['public_rank'], '.', color=cp[0], alpha=.5)

ticks = [1, 10, 50, 100, 500, 1000, 5000]
plt.xticks(np.log10(ticks), ticks)
ticks = [1, 10, 50, 100, 500, 1000]
plt.yticks(np.log10(ticks), ticks)

plt.title("Rank")
plt.xlabel("Private rank")
plt.ylabel("Public rank");

# %%
cp = sns.color_palette(n_colors=2)

pdf = metrics[['public_fb', 'private_fb']].dropna()
#pdf = pdf.sort_values(by='public_fb', ascending=False).iloc[0:1000]

pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="dense"))], axis=1)
pdf.columns = ['public', 'private', 'public_rank', 'private_rank']

# v, w = v + np.random.normal(0, .1, len(pdf)), w + np.random.normal(0,.1,len(pdf))
# pdf = pdf.apply(lambda x: x.map(lambda x: np.log10(x) if pd.notnull(x) else None))
pdf = pdf.apply(lambda x: x + np.random.normal(0, .1, len(x)), axis=0)

fig, ax = plt.subplots(figsize=(9, 6))

plt.plot(pdf['private_rank'], pdf['public_rank'], '.', color=cp[0], alpha=1)

# ticks = [1, 10, 50, 100, 500, 1000, 5000]
# plt.xticks(np.log10(ticks), ticks)
# plt.yticks(np.log10(ticks), ticks)

plt.title("Rank")
plt.xlabel("Private rank")
plt.ylabel("Public rank");

# %%
cp = sns.color_palette(n_colors=2)

pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="min"))], axis=1)
pdf.columns = ['public', 'private', 'public_rank', 'private_rank']

pdf = pdf.apply(lambda x: x.map(lambda x: np.log10(x) if pd.notnull(x) else None))
pdf = pdf.apply(lambda x: x + np.random.normal(0, .025, len(x)), axis=0)

fig, ax = plt.subplots(figsize=(8, 8))

plt.plot(pdf['private'], pdf['public'], '.', color=cp[0], alpha=1)

ticks = [1, 10, 50, 100, 500, 1000, 5000]
plt.xticks(np.log10(ticks), ticks)
plt.yticks(np.log10(ticks), ticks)

plt.title("Shares")
plt.xlabel("private")
plt.ylabel("public");

# %%
methods = ["pearson", "spearman", "kendall"]
corrs = pd.DataFrame(columns=methods)

for method in methods:
    df = metrics[['public_fb', 'private_fb']].dropna()
    df = df.sort_values(by='public_fb', ascending=False).iloc[1000:5000]
    df = np.log(df)
    print("{}: {:.2f}".format(method, df.corr(method=method).values[1,0]))
# Out:
# pearson: 0.39
# spearman: 0.38
# kendall: 0.30

# %%
methods = ["pearson", "spearman", "kendall"]
corrs = pd.DataFrame(columns=methods)

for year in range(2013, 2018):
    for method in methods:
        df = metrics[['public_fb', 'private_fb']].dropna()
        #df = df.sort_values(by='public_fb', ascending=False).iloc[0:1000]
        df = df[df.index.isin(yearly_articles[year])]
        #df = np.log(df)
        corrs.loc[year, method] = df.corr(method=method).values[1,0]
corrs.plot()
plt.title("Correlation - private shares & public shares")
# Out:
# Text(0.5,1,'Correlation - private shares & public shares')

# %%
pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf = pd.concat([pdf, pdf.apply(lambda x: x.rank(ascending=False, method="dense"))], axis=1)
pdf.columns = ['public', 'private', 'public_rank', 'private_rank']

pdf.corr("kendall")
# Out:
#               public  private  public_rank  private_rank
# public          1.00     0.44        -1.00         -0.44
# private         0.44     1.00        -0.44         -1.00
# public_rank    -1.00    -0.44         1.00          0.44
# private_rank   -0.44    -1.00         0.44          1.00

# %%
methods = ["pearson", "spearman", "kendall"]
corrs = pd.DataFrame(columns=methods)

for year in range(2013, 2018):
    for method in methods:
        df = metrics[metrics.index.isin(yearly_articles[year])][['public_fb', 'private_fb']]
        df = np.log(df)
        corrs.loc[year, method] = df.corr(method=method).values[1,0]
corrs.plot()
plt.title("Correlation - log(private shares) & log(public shares)")
# Out:
# Text(0.5,1,'Correlation - log(private shares) & log(public shares)')

# %%
x, y = (2, 2)
h = 6
plt.figure(figsize=(h*(x/y),h))

pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf = pdf[pdf.private_fb != pdf.public_fb]
total = len(pdf)

pdf = pdf.sample(frac=1)

# add noice to jitter scatterplot
v, w = pdf['private_fb'], pdf['public_fb']
v, w = v + np.random.normal(0, .1, len(pdf)), w + np.random.normal(0,.1,len(pdf))
v, w = np.log10(v), np.log10(w)

# Plotting
plt.plot(range(0,1000), alpha=.7) # diagonal
plt.scatter(v, w, marker='o', color='r', alpha=0.15)
sns.kdeplot(v, w, clip=(0,200), cmap='magma_r', alpha=.7)

# datapoints in plot area
dp_in_plot = pdf[(v<=x) & (w<=y)]

# datapoints in left and right area
dp_in_left = pdf[v<w]
dp_in_right = pdf[v>w]

plt.title("{:.2f}% shown".format(100*len(dp_in_plot)/total))
plt.text(0.15*x, 0.9*y, "{:.2f}%".format(100*len(dp_in_left)/total))
plt.text(0.85*x, 0.15*y, "{:.2f}%".format(100*len(dp_in_right)/total))

plt.ylabel('Public')
plt.xlabel('Private')

ticks = list(range(1,11)) + [50, 100]
plt.xticks(np.log10(ticks), ticks)
plt.yticks(np.log10(ticks), ticks)

plt.ylim(0,y)
plt.xlim(0,x);

# %%
x, y = (4, 4)
h = 6
plt.figure(figsize=(h*(x/y),h))

pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf = pdf[pdf.private_fb != pdf.public_fb]
total = len(pdf)

pdf = pdf.sample(frac=1)

# add noice to jitter scatterplot
v, w = pdf['private_fb'], pdf['public_fb']
v, w = v + np.random.normal(0, .1, len(pdf)), w + np.random.normal(0,.1,len(pdf))
v, w = np.log10(v), np.log10(w)

# Plotting
plt.plot(range(0,1000), alpha=.7) # diagonal
plt.scatter(v, w, marker='o', color='r', alpha=0.15)
# sns.kdeplot(v, w, clip=(0,200), cmap='magma_r', alpha=.7)

# datapoints in plot area
dp_in_plot = pdf[(v<=x) & (w<=y)]

# datapoints in left and right area
dp_in_left = pdf[v<w]
dp_in_right = pdf[v>w]

plt.title("{:.2f}% shown".format(100*len(dp_in_plot)/total))
plt.text(0.15*x, 0.9*y, "{:.2f}%".format(100*len(dp_in_left)/total))
plt.text(0.85*x, 0.15*y, "{:.2f}%".format(100*len(dp_in_right)/total))

plt.ylabel('Public')
plt.xlabel('Private')

ticks = [1, 10, 50, 100, 500, 1000, 5000]
plt.xticks(np.log10(ticks), ticks)
plt.yticks(np.log10(ticks), ticks)

plt.ylim(0,y)
plt.xlim(0,x);

# %%
fig, axes = plt.subplots(3, 2, figsize=(12, 16), sharex=True, sharey=True)

for year, ax in zip(range(2013, 2018), axes.reshape(-1)):
    if not year:
        ax.axis('off')
        
    # Plot settings
    x, y = (4, 4)
    h = 6
    
    # Prepare data
    dois = articles[articles.year == year].index
    pdf = metrics.reindex(dois)
    pdf = pdf[['public_fb', 'private_fb']].dropna()
    pdf = pdf[pdf.private_fb != pdf.public_fb]
    total = len(pdf)
    
    pdf = pdf.sample(frac=1)

    # add noice to jitter scatterplot
    v, w = pdf['private_fb'], pdf['public_fb']
    v, w = v + np.random.normal(0, .1, len(pdf)), w + np.random.normal(0,.1,len(pdf))
    v, w = np.log10(v), np.log10(w)
    
    # datapoints in plot area
    dp_in_plot = pdf[(v<=x) & (w<=y)]
    
    # datapoints in left and right area
    dp_in_left = pdf[v<w]
    dp_in_right = pdf[v>w]
    
    # Plotting
    ax.plot(range(0,1000), alpha=.7) # diagonal
    ax.scatter(v, w, marker='o', color='r', alpha=0.15)
    # sns.kdeplot(pdf['shares>0'], pdf['facebook'], clip=(0,200), cmap='magma_r', alpha=.7)

    # Labels
    ax.set_title("{} ({:.2f}% shown)".format(year, 100*len(dp_in_plot)/total))
    ax.text(0.2, 3.5, "{:.2f}%".format(100*len(dp_in_left)/total))
    ax.text(3.2, 0.5, "{:.2f}%".format(100*len(dp_in_right)/total))
    ax.set_ylabel('Public')
    ax.set_xlabel('Private')
    ax.set_ylim(0,y)
    ax.set_xlim(0,x);

# %%
pdf = metrics[['public_fb', 'private_fb']].dropna()
pdf['diff'] = metrics['private_fb'] - metrics['public_fb']
pdf.describe()
# Out:
#        public_fb  private_fb      diff
# count   12882.00    12882.00  12882.00
# mean        3.65       15.75     12.10
# std        24.63      137.98    136.96
# min         1.00        1.00  -2393.00
# 25%         1.00        1.00      0.00
# 50%         1.00        3.00      2.00
# 75%         2.00        9.00      6.00
# max      2428.00    12473.00  12427.00

# %% [markdown]
# ### Correlations

# %%
# Compute the correlation matrix
corr = metrics[metrics.columns.difference(['total', 'diff'])].corr(method="spearman")

# Draw the heatmap with the mask and correct aspect ratio
with sns.axes_style("white"):
    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(11, 9))

    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, annot=True, fmt=".2f",
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
# Compute the correlation matrix
rel_metrics = [_+">0" for _ in fb_metrics] + ['facebook', 'twitter']
drop_metrics = fb_metrics + ['total', 'diff', 'diff>0', 'linkedin', 'pinterest']
corr = metrics[metrics.columns.difference(drop_metrics)].dropna().corr(method="spearman")
corr = corr.loc[rel_metrics, corr.columns.difference(rel_metrics)]
# corr = corr.sort_index()

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(16, 8))
    
    cmap = sns.diverging_palette(220, 10, as_cmap=True)
    
    sns.heatmap(corr, cmap=cmap, center=0, annot=True, fmt=".2f",
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
rel_metrics = [_+">0" for _ in ['shares']] + ['facebook', 'twitter']
drop_metrics = fb_metrics + ['total', 'diff', 'diff>0', 'linkedin', 'pinterest']

cmap = sns.diverging_palette(220, 10, as_cmap=True)

with sns.axes_style("white"):
    f, axes = plt.subplots(5, 1, figsize=(16, 24))
    for ax, sel_year in zip(axes, range(2013, 2018)):
        ax.set_title(sel_year)
        tdf = metrics.reindex(details[details.year == sel_year].doi)
        corr = tdf[tdf.columns.difference(drop_metrics)].corr(method="spearman")
        corr = corr.loc[rel_metrics, corr.columns.difference(rel_metrics)]
        # corr = corr.sort_index()

        sns.heatmap(corr, cmap=cmap, center=0, annot=True, fmt=".2f", vmax=1, vmin=-.2,
                square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %%
# Compute the correlation matrix

corr = metrics[['shares>0', 'reactions>0', 'comments>0', 'facebook']].fillna(0).corr(method="spearman")

# Draw the heatmap with the mask and correct aspect ratio
with sns.axes_style("white"):
    # Generate a mask for the upper triangle
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True

    f, ax = plt.subplots(figsize=(11, 9))

    cmap = sns.diverging_palette(220, 10, as_cmap=True)

    sns.heatmap(corr, mask=mask, cmap=cmap, center=0, annot=True, fmt=".2f",
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
(metrics['diff>0']>0).sum(), (metrics['diff>0']==0).sum(), (metrics['diff>0']<0).sum()
# Out:
# (8415, 3307, 1160)

# %%
pdf = metrics[metrics['diff>0'] != 0][['diff>0']].copy()
pdf['type'] = pdf['diff>0'].map(lambda x: "Private" if x > 0 else "Public")
pdf['diff>0'] = pdf['diff>0'].abs()
sns.boxplot(x="diff>0", y="type", data=pdf, notch=True)
pdf['diff>0'] = pdf['diff>0'] + np.random.normal(0,.25,len(pdf))
sns.stripplot(x="diff>0", y="type", data=pdf, jitter=True, color=".25", alpha=.1, size=3)
plt.xlim(0, 33);

# %%
#ax = sns.distplot(diff, hist=False, norm_hist=True);
pdf = metrics.merge(articles[['year']], left_index=True, right_index=True, how="left").melt("year", ["diff>0"])
# sns.stripplot(x="year", y="value", hue="variable", data=pdf, size=2.5, dodge=True, jitter=True, alpha=.15)
sns.boxplot(x="year", y="value", hue="variable", data=pdf)
plt.ylim(-15, 20)
# Out:
# (-15, 20)

# %%
#ax = sns.distplot(diff, hist=False, norm_hist=True);
pdf = metrics.merge(articles[['year']], left_index=True, right_index=True, how="left").melt("year", ["diff>0"])
sns.stripplot(x="year", y="value", hue="variable", data=pdf, size=2.5, dodge=True, jitter=True, alpha=.15)
#sns.boxplot(x="year", y="value", hue="variable", data=pdf)
plt.ylim(-50, 100)
# Out:
# (-50, 100)

# %%
#ax = sns.distplot(diff, hist=False, norm_hist=True);
pdf = metrics.merge(articles[['year']], left_index=True, right_index=True, how="left").melt("year", ["shares>0", "facebook"])
ax = sns.stripplot(x="year", y="value", hue="variable", data=pdf, marker=".", dodge=True, jitter=True, alpha=.15)
plt.ylim(-10,300);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d215f75ceaf4> in <module>()
#       1 #ax = sns.distplot(diff, hist=False, norm_hist=True);
# ----> 2 pdf = metrics.merge(articles[['year']], left_index=True, right_index=True, how="left").melt("year", ["shares>0", "facebook"])
#       3 ax = sns.stripplot(x="year", y="value", hue="variable", data=pdf, marker=".", dodge=True, jitter=True, alpha=.15)
#       4 plt.ylim(-10,300);
#
# NameError: name 'metrics' is not defined

# %% [markdown]
# ## Raindrop plots

# %%
pdf = metrics.merge(details[['doi', 'year']], left_index=True, right_on="doi", how="left")
pdf = pdf.melt(value_vars=["public_fb", "private_fb"], id_vars="year", var_name="group", value_name="private_fb").dropna()
# pdf = pdf.sample(21000)
pdf['private_fb'] = np.log10(pdf['private_fb'])

# Plot the repeated measures data
dx = "year"; dy = "private_fb"; dhue = "group"; ort = "h"; pal = "Set2"; sigma = .1

ax=pt.RainCloud(x = dx, y = dy, hue = dhue, data = pdf, palette = pal, bw = sigma, width_viol = .7,
                figsize = (12,12), orient = ort , alpha = .6, dodge = True, pointplot = False, move = .2)

ticks = list(range(11)) + [50, 100, 500, 1000]
plt.xticks(np.log10(ticks), ticks)
plt.xlim(-0.1,4)
# Out:
# /home/asura/.virtualenvs/altmetrics/lib/python3.5/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log10
#   del sys.path[0]
# (-0.1, 4)

# %% [markdown]
# ## Others

# %% [markdown]
# ## Publication date & latest date of sharing

# %%
details['pub_to_latest_share'] = (details.og_updated_time - details.publication_date)
details['pub_to_latest_share'] = details['pub_to_latest_share'].map(lambda x: x.days)

# merge with metrics
# tdf = metrics.merge(details[['pub_to_latest_share', 'doi']], left_index=True, right_on="doi", how="left")

details.pub_to_latest_share.describe()
# Out:
# count    144591.00
# mean        412.34
# std         397.14
# min         -20.00
# 25%          85.00
# 50%         322.00
# 75%         587.00
# max        2015.00
# Name: pub_to_latest_share, dtype: float64

# %%
a = details.reset_index().groupby(["type", "og_id"])[['shares']].first().groupby(["type"]).mean()
a['median'] = details.reset_index().groupby(["type", "og_id"])['shares'].first().groupby(["type"]).median()
a['n'] = details.reset_index().groupby(["type", "og_id"]).first().groupby(["type"]).size()
a.rename(columns = {'shares':'mean'})
# Out:
#             mean  median      n
# type
# authors    81.85       3    533
# comments  241.59       2    181
# doi        37.76       2   1921
# doi_old     5.12       0  37141
# landing     2.26       0  89855
# metrics     5.82       0  11524
# pdf         0.47       0   3987
# pmc         1.62       0     66
# pmid        0.61       0     64
# related   175.69       3    182

# %% [markdown]
# ## Top papers

# %%
for doi, v in metrics['private_fb'].sort_values(ascending=False).head(10).items():
    print("https://dx.doi.org/{},{}".format(doi, v))
# Out:
# https://dx.doi.org/10.1371/journal.pone.0141854,12473.0
# https://dx.doi.org/10.1371/journal.pone.0153419,4181.0
# https://dx.doi.org/10.1371/journal.pone.0185809,3415.0
# https://dx.doi.org/10.1371/journal.pone.0131613,3360.0
# https://dx.doi.org/10.1371/journal.pone.0072991,2612.0
# https://dx.doi.org/10.1371/journal.pone.0147905,1908.0
# https://dx.doi.org/10.1371/journal.pone.0110509,1795.0
# https://dx.doi.org/10.1371/journal.pone.0055937,1722.0
# https://dx.doi.org/10.1371/journal.pone.0112065,1709.0
# https://dx.doi.org/10.1371/journal.pone.0146193,1642.0

# %%
for doi, v in metrics['public_fb'].sort_values(ascending=False).head(10).items():
    print("https://dx.doi.org/{},{}".format(doi, v))
# Out:
# https://dx.doi.org/10.1371/journal.pone.0095492,2428.0
# https://dx.doi.org/10.1371/journal.pone.0103760,881.0
# https://dx.doi.org/10.1371/journal.pone.0070182,488.0
# https://dx.doi.org/10.1371/journal.pone.0089934,411.0
# https://dx.doi.org/10.1371/journal.pone.0105225,367.0
# https://dx.doi.org/10.1371/journal.pone.0110489,341.0
# https://dx.doi.org/10.1371/journal.pone.0111629,310.0
# https://dx.doi.org/10.1371/journal.pone.0113505,304.0
# https://dx.doi.org/10.1371/journal.pone.0088278,267.0
# https://dx.doi.org/10.1371/journal.pone.0111913,264.0

# %%
df_both = metrics.loc[both_shares]
for doi, v in (df_both['public_fb']-df_both['private_fb']).sort_values(ascending=False).head(10).items():
    print("https://dx.doi.org/{},{}".format(doi, v))
# Out:
# https://dx.doi.org/10.1371/journal.pone.0095492,2393.0
# https://dx.doi.org/10.1371/journal.pone.0089934,330.0
# https://dx.doi.org/10.1371/journal.pone.0110489,314.0
# https://dx.doi.org/10.1371/journal.pone.0113505,193.0
# https://dx.doi.org/10.1371/journal.pone.0113605,108.0
# https://dx.doi.org/10.1371/journal.pone.0111086,106.0
# https://dx.doi.org/10.1371/journal.pone.0081877,87.0
# https://dx.doi.org/10.1371/journal.pone.0100599,79.0
# https://dx.doi.org/10.1371/journal.pone.0113294,77.0
# https://dx.doi.org/10.1371/journal.pone.0082429,68.0

# %%
for doi, v in (df_both['private_fb']-df_both['public_fb']).sort_values(ascending=False).head(10).items():
    print("https://dx.doi.org/{},{}".format(doi, v))
# Out:
# https://dx.doi.org/10.1371/journal.pone.0141854,12427.0
# https://dx.doi.org/10.1371/journal.pone.0153419,4157.0
# https://dx.doi.org/10.1371/journal.pone.0131613,3335.0
# https://dx.doi.org/10.1371/journal.pone.0185809,3277.0
# https://dx.doi.org/10.1371/journal.pone.0072991,2586.0
# https://dx.doi.org/10.1371/journal.pone.0147905,1829.0
# https://dx.doi.org/10.1371/journal.pone.0110509,1684.0
# https://dx.doi.org/10.1371/journal.pone.0146193,1607.0
# https://dx.doi.org/10.1371/journal.pone.0112065,1526.0
# https://dx.doi.org/10.1371/journal.pone.0055937,1472.0
